# %% [markdown]
# Test 7

# %%
# %run simulation.py
# Out:
# Hello! Welcome to our simulation. The instructions below are designed to have an interactive simulation process.
#
# After you read the instructions, please type 'ok' to continue.
#
# First, ypu have to indicate the environment area. Please type the length of cell size after you are asked.
#
# Then, please indicate the target location with a space between. (ex: '25 25') after you are asked.
#
# After that, please indicate the location of obstacles OR pedestrians as stated below.
#
#
# For obstacles: 'o x y', where x and y indicate the x and y coordinate locations, from 0 until cell size you provided (that is excluded.).
#
#
# For pedestrians: 'p x y', where x and y indicate the x and y coordinate locations.
#
# When you are done, please write 'exit'. Thank you!
#
# Please enter the simulation run time. (Ex: 25) If there is no specific time requirement, please write 0.
# 0
# Please type 0 for simulation without speed involved. Else, type 1.
# 1
# Please indicate the width of the area
# ...

# %%
# %run simulation.py
# Out:
# Hello! Welcome to our simulation. The instructions below are designed to have an interactive simulation process.
#
# First, you have to indicate the environment area. Please type the length of cell size after you are asked.
#
# Then, please indicate the target location with a space between. (ex: '25 25') after you are asked.
#
# After that, please indicate the location of obstacles OR pedestrians as stated below.
#
#
# For obstacles: 'o x y', where x and y indicate the x and y coordinate locations, from 0 until cell size you provided (that is excluded.).
#
#
# For pedestrians: 'p x y', where x and y indicate the x and y coordinate locations.
#
# When you are done, please write 'exit'. Thank you!
#
# Please enter the simulation run time. (Ex: 25) If there is no specific time requirement, please write 0.
# 0
# Please type 0 for simulation without speed involved. Else, type 1.
# 1
# Please indicate the width of the area
# 12
# Please indicate the height of the area
# 10
#
# ...

# %%
# %run simulation.py
# Out:
# Hello! Welcome to our simulation. The instructions below are designed to have an interactive simulation process.
#
# First, you have to indicate the environment area. Please type the length of cell size after you are asked.
#
# Then, please indicate the target location with a space between. (ex: '25 25') after you are asked.
#
# After that, please indicate the location of obstacles OR pedestrians as stated below.
#
#
# For obstacles: 'o x y', where x and y indicate the x and y coordinate locations, from 0 until cell size you provided (that is excluded.).
#
#
# For pedestrians: 'p x y', where x and y indicate the x and y coordinate locations.
#
# When you are done, please write 'exit'. Thank you!
#
# Please enter the simulation run time. (Ex: 25) If there is no specific time requirement, please write 0.
# 0
# Please type 0 for simulation without speed involved. Else, type 1.
# 1
# Please indicate the width of the area
# 30
# Please indicate the height of the area
# 30
#
# ...

# %%
# %run simulation.py
# Out:
# Hello! Welcome to our simulation. The instructions below are designed to have an interactive simulation process.
#
# First, you have to indicate the environment area. Please type the length of cell size after you are asked.
#
# Then, please indicate the target location with a space between. (ex: '25 25') after you are asked.
#
# After that, please indicate the location of obstacles OR pedestrians as stated below.
#
#
# For obstacles: 'o x y', where x and y indicate the x and y coordinate locations, from 0 until cell size you provided (that is excluded.).
#
#
# For pedestrians: 'p x y', where x and y indicate the x and y coordinate locations.
#
# When you are done, please write 'exit'. Thank you!
#
# Please enter the simulation run time. (Ex: 25) If there is no specific time requirement, please write 0.
# 25
# Please type 0 for simulation without speed involved. Else, type 1.
# 0
# ...

# %%
# %run simulation.py
# Out:
# Hello! Welcome to our simulation. The instructions below are designed to have an interactive simulation process.
#
# First, you have to indicate the environment area. Please type the length of cell size after you are asked.
#
# Then, please indicate the target location with a space between. (ex: '25 25') after you are asked.
#
# After that, please indicate the location of obstacles OR pedestrians as stated below.
#
#
# For obstacles: 'o x y', where x and y indicate the x and y coordinate locations, from 0 until cell size you provided (that is excluded.).
#
#
# For pedestrians: 'p x y', where x and y indicate the x and y coordinate locations.
#
# When you are done, please write 'exit'. Thank you!
#
# Please enter the simulation run time. (Ex: 25) If there is no specific time requirement, please write 0.
# 0
# Please type 0 for simulation without speed involved. Else, type 1.
# 1
# Please indicate the width of the area
# 100
# Please indicate the height of the area
# 5
#
# ...

# %%
# %run simulation.py
# Out:
# Hello! Welcome to our simulation. The instructions below are designed to have an interactive simulation process.
#
# First, you have to indicate the environment area. Please type the length of cell size after you are asked.
#
# Then, please indicate the target location with a space between. (ex: '25 25') after you are asked.
#
# After that, please indicate the location of obstacles OR pedestrians as stated below.
#
#
# For obstacles: 'o x y', where x and y indicate the x and y coordinate locations, from 0 until cell size you provided (that is excluded.).
#
#
# For pedestrians: 'p x y', where x and y indicate the x and y coordinate locations.
#
# When you are done, please write 'exit'. Thank you!
#
# Please enter the simulation run time. (Ex: 25) If there is no specific time requirement, please write 0.
# 25
# Please type 0 for simulation without speed involved. Else, type 1.
# 0
# ...

# %%
# %run simulation.py
# Out:
# Hello! Welcome to our simulation. The instructions below are designed to have an interactive simulation process.
#
# First, you have to indicate the environment area. Please type the length of cell size after you are asked.
#
# Then, please indicate the target location with a space between. (ex: '25 25') after you are asked.
#
# After that, please indicate the location of obstacles OR pedestrians as stated below.
#
#
# For obstacles: 'o x y', where x and y indicate the x and y coordinate locations, from 0 until cell size you provided (that is excluded.).
#
#
# For pedestrians: 'p x y', where x and y indicate the x and y coordinate locations.
#
# When you are done, please write 'exit'. Thank you!
#
# Please enter the simulation run time. (Ex: 25) If there is no specific time requirement, please write 0.
# 25
# Please type 0 for simulation without speed involved. Else, type 1.
# 0
# ...
